# %%
from scipy.io import loadmat
from os import listdir
from os.path import isfile, join
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import shutil

# %%
video_name = 'MVI_1469_VIS'
frame = '300'

# %%
# 이미지 읽어와서 파일 저장

im_save = Image.open("img/" + video_name + "_frame" + frame +".jpg")
im = np.array(im_save, dtype=np.uint8)

# 이미지 저장
im_save.save(video_name + "_frame" + frame +"_sample.jpg")

print(im.shape)
# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im) # y축, x축, 채널수
# 축, 테두리, 공백 없애고 사진 저장
plt.axis('off')

plt.show()
# Out:
# (1080, 1920, 3)

# %%
r = open("img/" + video_name + "_frame" + frame +".txt", mode='rt', encoding='utf-8')
r.read(500)
# Out:
# '2 0.703179 0.490259 0.205282 0.176471\n2 0.297995 0.467009 0.178048 0.115405\n3 0.160148 0.518470 0.029037 0.050420\n1 0.149547 0.612267 0.051321 0.132053\n2 0.103246 0.446680 0.100615 0.086435\n2 0.868464 0.534677 0.043531 0.085234\n2 0.038264 0.486657 0.076528 0.037215\n2 0.899109 0.559247 0.118912 0.036253\n2 0.199428 0.480655 0.032413 0.030012\n3 0.603711 0.542718 0.037050 0.021609\n'

# %%
print("2 0.703179 0.490259 0.205282 0.176471\n2 0.297995 0.467009 0.178048 0.115405\n3 0.160148 0.518470 0.029037 0.050420\n1 0.149547 0.612267 0.051321 0.132053\n2 0.103246 0.446680 0.100615 0.086435\n2 0.868464 0.534677 0.043531 0.085234\n2 0.038264 0.486657 0.076528 0.037215\n2 0.899109 0.559247 0.118912 0.036253\n2 0.199428 0.480655 0.032413 0.030012\n3 0.603711 0.542718 0.037050 0.021609\n")
# Out:
# 2 0.703179 0.490259 0.205282 0.176471
# 2 0.297995 0.467009 0.178048 0.115405
# 3 0.160148 0.518470 0.029037 0.050420
# 1 0.149547 0.612267 0.051321 0.132053
# 2 0.103246 0.446680 0.100615 0.086435
# 2 0.868464 0.534677 0.043531 0.085234
# 2 0.038264 0.486657 0.076528 0.037215
# 2 0.899109 0.559247 0.118912 0.036253
# 2 0.199428 0.480655 0.032413 0.030012
# 3 0.603711 0.542718 0.037050 0.021609
